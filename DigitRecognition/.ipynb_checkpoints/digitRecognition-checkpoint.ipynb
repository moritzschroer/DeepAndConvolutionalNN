# %%
import keras as keras
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D

from readData import readData

from plotDigits import predictAndPlot, plotDigit
# Out:
# 2024-05-12 21:46:42.193983: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# initialisierung des Modells
model = Sequential()
model.add(Dense(600, activation='relu', input_shape=(784, ),name = "first_layer"))
model.add(Dense(400, activation='relu',  name = "hidden_layer_1"))
model.add(Dense(100, activation='relu',  name = "hidden_layer_2"))
model.add(Dense(10, activation = 'softmax', name = "output_layer"))
# Out:
# /Users/moritzschroer/miniconda3/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# kompilieren des Modells
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Einlesen der Trainingsdaten und Testdaten
train_length = 59000
test_length = 500
train_data, training_verification_data, test_data, test_verificarion_data = readData(train_length, test_length)
# Out:
# Lese 59000 Trainingsdaten ein:
# HBox(children=(HTML(value=''), IntProgress(value=0, max=59000)))
# Lese 500 Testdaten ein
# HBox(children=(HTML(value=''), IntProgress(value=0, max=500)))

# %%
# Trainieren des Modells
model.fit(train_data, training_verification_data, epochs=10, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/10
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8703 - loss: 0.4527 - val_accuracy: 0.9593 - val_loss: 0.1301
# Epoch 2/10
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9705 - loss: 0.0912 - val_accuracy: 0.9641 - val_loss: 0.1131
# Epoch 3/10
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9814 - loss: 0.0566 - val_accuracy: 0.9751 - val_loss: 0.0830
# Epoch 4/10
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9879 - loss: 0.0389 - val_accuracy: 0.9753 - val_loss: 0.0819
# Epoch 5/10
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9906 - loss: 0.0291 - val_accuracy: 0.9755 - val_loss: 0.0872
# Epoch 6/10
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9931 - loss: 0.0205 - val_accuracy: 0.9772 - val_loss: 0.0850
# Epoch 7/10
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9936 - loss: 0.0185 - val_accuracy: 0.9768 - val_loss: 0.0857
# Epoch 8/10
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9948 - loss: 0.0167 - val_accuracy: 0.9735 - val_loss: 0.1109
# Epoch 9/10
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9936 - loss: 0.0188 - val_accuracy: 0.9753 - val_loss: 0.1061
# Epoch 10/10
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9949 - loss: 0.0164 - val_accuracy: 0.9705 - val_loss: 0.1310

# %%
# Testen des Modells
test_loss, test_acc = model.evaluate(test_data, test_verificarion_data)
print('Test accuracy:', test_acc)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0375
# Test accuracy: 0.9819999933242798

# %%
# Plotten einiger vom Modell vorhergesagten Ziffern 
predictAndPlot(model, test_data, test_verificarion_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
